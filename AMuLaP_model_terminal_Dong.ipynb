# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !pip install kora
from kora import console
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 43.6 MB/s eta 0:00:00
# ...

# %%
console.start() #连接terminal

# %% [markdown]
# 在 terminal中输入

# %%
from os import RTLD_DEEPBIND
% cd gdrive/MyDrive/AMuLaP
% cd gdrive/Shareddrives/CSCI544-Project/AMuLaP

% pip install -r requirements.txt

#seed可改为13 21 42 87 100，seed改动16-42之类的也要改动
% python run_prompt.py \
    --model_name_or_path roberta-large \
    --task_name cola \
    --data_dir data/k-shot/CoLAa/16-13 \
    --output_dir outputsa \
    --shot_num 16\
    --seed 13 \
    --max_train_steps 1000 \
    --num_warmup_steps 0 \
    --eval_steps 100 \
    --learning_rate 1e-5 \
    --per_device_train_batch_size 8 \
    --per_device_eval_batch_size 8 \
    --top_k 16\
    --max_seq_len 128 \
    AutoL \
    --template *cls**sent_0*_It_was*mask*.*sep+* \
    --mapping_path auto_label_mapping/CoLA/16-13.sort.txt
    

python run_prompt.py \
    --model_name_or_path roberta-large \
    --task_name cola \
    --data_dir data/k-shot/CoLAa/16-13 \
    --output_dir outputsa \
    --shot_num 16\
    --seed 13 \
    --max_train_steps 1000 \
    --num_warmup_steps 0 \
    --eval_steps 100 \
    --learning_rate 1e-5 \
    --per_device_train_batch_size 8 \
    --per_device_eval_batch_size 8 \
    --top_k 16\
    --max_seq_len 128 \
    AutoL \
    --template *cls**sent_0*_It_was*mask*.*sep+* \
    --mapping_path auto_label_mapping/CoLA/16-13.sort.txt

cola

python run_prompt.py \
    --model_name_or_path roberta-large \
    --task_name cola \
    --data_dir data/k-shot/CoLAa/16-13 \
    --output_dir outputsa \
    --shot_num 16\
    --seed 13 \
    --max_train_steps 1000 \
    --num_warmup_steps 0 \
    --eval_steps 100 \
    --learning_rate 1e-5 \
    --per_device_train_batch_size 8 \
    --per_device_eval_batch_size 8 \
    --top_k 16\
    --max_seq_len 128 \
    AutoL \
    --template *cls**sent_0*_It_was*mask*.*sep+* \
    --mapping_path auto_label_mapping/CoLA/16-13.sort.txt

sst2

python run_prompt.py \
    --model_name_or_path roberta-large \
    --task_name sst2 \
    --data_dir data/k-shot/SST-2a/16-13 \
    --output_dir outputsa \
    --shot_num 16\
    --seed 13 \
    --max_train_steps 1000 \
    --num_warmup_steps 0 \
    --eval_steps 100 \
    --learning_rate 1e-5 \
    --per_device_train_batch_size 8 \
    --per_device_eval_batch_size 8 \
    --top_k 16\
    --max_seq_len 128 \
    AutoL \
    --template *cls**sent_0*_It_was*mask*.*sep+* \
    --mapping_path auto_label_mapping/SST-2/16-13.sort.txt

QNLI

python run_prompt.py \
    --model_name_or_path roberta-large \
    --task_name qnli \
    --data_dir data/k-shot/QNLIa/16-13 \
    --output_dir outputsa \
    --shot_num 16\
    --seed 13 \
    --max_train_steps 1000 \
    --num_warmup_steps 0 \
    --eval_steps 100 \
    --learning_rate 1e-5 \
    --per_device_train_batch_size 8 \
    --per_device_eval_batch_size 8 \
    --top_k 16\
    --max_seq_len 128 \
    AutoL \
    --template *cls**sent-_0*?*mask*,*+sentl_1**sep+* \
    --mapping_path auto_label_mapping/QNLI/16-13.sort.txt

RTE(cuda out of memory)

python run_prompt.py \
    --model_name_or_path roberta-large \
    --task_name rte \
    --data_dir data/k-shot/RTEa/16-13 \
    --output_dir outputsa \
    --shot_num 16\
    --seed 13 \
    --max_train_steps 1000 \
    --num_warmup_steps 0 \
    --eval_steps 100 \
    --learning_rate 1e-5 \
    --per_device_train_batch_size 8 \
    --per_device_eval_batch_size 8 \
    --top_k 16\
    --max_seq_len 128 \
    AutoL \
    --template *cls**sent-_0*?*mask*,*+sentl_1**sep+* \
    --max_seq_len 256 --first_sent_limit 240 \
    --mapping_path auto_label_mapping/RTE/16-13.sort.txt

MRPC(not exist)

python run_prompt.py \
    --model_name_or_path roberta-large \
    --task_name mrpc \
    --data_dir data/k-shot/MRPCa/16-13 \
    --output_dir outputsa \
    --shot_num 16\
    --seed 13 \
    --max_train_steps 1000 \
    --num_warmup_steps 0 \
    --eval_steps 100 \
    --learning_rate 1e-5 \
    --per_device_train_batch_size 8 \
    --per_device_eval_batch_size 8 \
    --top_k 16\
    --max_seq_len 128 \
    AutoL \
    --template *cls**sent_0**mask*,*+sentl_1**sep+* \
    --mapping_path auto_label_mapping/MRPC/16-13.sort.txt


MNLI
python run_prompt.py \
    --model_name_or_path roberta-large \
    --task_name mnli \
    --data_dir data/k-shot/MNLIa/16-13 \
    --output_dir outputsa \
    --shot_num 16\
    --seed 13 \
    --max_train_steps 1000 \
    --num_warmup_steps 0 \
    --eval_steps 100 \
    --learning_rate 1e-5 \
    --per_device_train_batch_size 8 \
    --per_device_eval_batch_size 8 \
    --top_k 16\
    --max_seq_len 256 \
    AutoL \
    --template *cls**sent-_0*?*mask*,*+sentl_1**sep+* \
    --max_seq_len 256 \
    --mapping_path auto_label_mapping/MNLI/16-13.sort.txt


QQP
python run_prompt.py \
    --model_name_or_path roberta-large \
    --task_name qqp \
    --data_dir data/k-shot/QQPa/16-13 \
    --output_dir outputsa \
    --shot_num 16\
    --seed 13 \
    --max_train_steps 1000 \
    --num_warmup_steps 0 \
    --eval_steps 100 \
    --learning_rate 1e-5 \
    --per_device_train_batch_size 8 \
    --per_device_eval_batch_size 8 \
    --top_k 16\
    --max_seq_len 128 \
    AutoL \
    --template *cls**sent_0**mask*,*+sentl_1**sep+* \
    --mapping_path auto_label_mapping/QQP/16-13.sort.txt
# Out:
# UsageError: Line magic function `%` not found.

# %%
cola

python run_prompt.py \
    --model_name_or_path roberta-large \
    --task_name cola \
    --data_dir data/k-shot/CoLAa/16-13 \
    --output_dir outputsa \
    --shot_num 16\
    --seed 13 \
    --max_train_steps 1000 \
    --num_warmup_steps 0 \
    --eval_steps 100 \
    --learning_rate 1e-5 \
    --per_device_train_batch_size 8 \
    --per_device_eval_batch_size 8 \
    --top_k 16\
    --max_seq_len 128 \
    AMuLaP \
    --template *cls**sent_0*_It_was*mask*.*sep+* \
    --mapping_path auto_label_mapping/CoLA/16-13.sort.txt

sst2

python run_prompt.py \
    --model_name_or_path roberta-large \
    --task_name sst2 \
    --data_dir data/k-shot/SST-2a/16-13 \
    --output_dir outputsa \
    --shot_num 16\
    --seed 13 \
    --max_train_steps 1000 \
    --num_warmup_steps 0 \
    --eval_steps 100 \
    --learning_rate 1e-5 \
    --per_device_train_batch_size 8 \
    --per_device_eval_batch_size 8 \
    --top_k 16\
    --max_seq_len 128 \
    AMuLaP \
    --template *cls**sent_0*_It_was*mask*.*sep+* \
    --mapping_path auto_label_mapping/SST-2/16-13.sort.txt

QNLI

python run_prompt.py \
    --model_name_or_path roberta-large \
    --task_name qnli \
    --data_dir data/k-shot/QNLIa/16-13 \
    --output_dir outputsa \
    --shot_num 16\
    --seed 13 \
    --max_train_steps 1000 \
    --num_warmup_steps 0 \
    --eval_steps 100 \
    --learning_rate 1e-5 \
    --per_device_train_batch_size 8 \
    --per_device_eval_batch_size 8 \
    --top_k 16\
    --max_seq_len 128 \
    AMuLaP \
    --template *cls**sent-_0*?*mask*,*+sentl_1**sep+* \
    --mapping_path auto_label_mapping/QNLI/16-13.sort.txt

RTE(cuda out of memory)

python run_prompt.py \
    --model_name_or_path roberta-large \
    --task_name rte \
    --data_dir data/k-shot/RTEa/16-13 \
    --output_dir outputsa \
    --shot_num 16\
    --seed 13 \
    --max_train_steps 1000 \
    --num_warmup_steps 0 \
    --eval_steps 100 \
    --learning_rate 1e-5 \
    --per_device_train_batch_size 8 \
    --per_device_eval_batch_size 8 \
    --top_k 16\
    --max_seq_len 128 \
    AMuLaP \
    --template *cls**sent-_0*?*mask*,*+sentl_1**sep+* \
    --max_seq_len 256 --first_sent_limit 240 \
    --mapping_path auto_label_mapping/RTE/16-13.sort.txt

MRPC(not exist)

python run_prompt.py \
    --model_name_or_path roberta-large \
    --task_name mrpc \
    --data_dir data/k-shot/MRPCa/16-13 \
    --output_dir outputsa \
    --shot_num 16\
    --seed 13 \
    --max_train_steps 1000 \
    --num_warmup_steps 0 \
    --eval_steps 100 \
    --learning_rate 1e-5 \
    --per_device_train_batch_size 8 \
    --per_device_eval_batch_size 8 \
    --top_k 16\
    --max_seq_len 128 \
    AMuLaP \
    --template *cls**sent_0**mask*,*+sentl_1**sep+* \
    --mapping_path auto_label_mapping/MRPC/16-13.sort.txt


MNLI
python run_prompt.py \
    --model_name_or_path roberta-large \
    --task_name mnli \
    --data_dir data/k-shot/MNLIa/16-13 \
    --output_dir outputsa \
    --shot_num 16\
    --seed 13 \
    --max_train_steps 1000 \
    --num_warmup_steps 0 \
    --eval_steps 100 \
    --learning_rate 1e-5 \
    --per_device_train_batch_size 8 \
    --per_device_eval_batch_size 8 \
    --top_k 16\
    --max_seq_len 256 \
    AMuLaP \
    --template *cls**sent-_0*?*mask*,*+sentl_1**sep+* \
    --max_seq_len 256 \
    --mapping_path auto_label_mapping/MNLI/16-13.sort.txt


QQP
python run_prompt.py \
    --model_name_or_path roberta-large \
    --task_name qqp \
    --data_dir data/k-shot/QQPa/16-13 \
    --output_dir outputsa \
    --shot_num 16\
    --seed 13 \
    --max_train_steps 1000 \
    --num_warmup_steps 0 \
    --eval_steps 100 \
    --learning_rate 1e-5 \
    --per_device_train_batch_size 8 \
    --per_device_eval_batch_size 8 \
    --top_k 16\
    --max_seq_len 128 \
    AMuLaP \
    --template *cls**sent_0**mask*,*+sentl_1**sep+* \
    --mapping_path auto_label_mapping/QQP/16-13.sort.txt

# %%
# python run_prompt.py \
#     --model_name_or_path roberta-large \
#     --task_name cola \
#     --data_dir data/k-shot/CoLA/16-13-b \
#     --output_dir outputs \
#     --shot_num 16\
#     --seed 13 \
#     --max_train_steps 1000 \
#     --num_warmup_steps 0 \
#     --eval_steps 100 \
#     --learning_rate 1e-5 \
#     --per_device_train_batch_size 8 \
#     --per_device_eval_batch_size 8 \
#     --top_k 16\
#     --max_seq_len 128 \
#     AutoL \
#     --template *cls**sent_0*_It_was*mask*.*sep+* \
#     --mapping_path auto_label_mapping/CoLA/16-13.sort.txt

# %% [markdown]
# 想要重启terminal就运一下这个

# %%
from google.colab import runtime
runtime.unassign()

# %%
python run_prompt.py \
    --model_name_or_path roberta-large \
    --task_name sst2 \
    --data_dir data/k-shot/CoLa/16-13-b \
    --output_dir outputs \
    --shot_num 16\
    --seed 13 \
    --max_train_steps 1000 \
    --num_warmup_steps 0 \
    --eval_steps 100 \
    --learning_rate 1e-5 \
    --per_device_train_batch_size 8 \
    --per_device_eval_batch_size 8 \
    --top_k 16\
    --max_seq_len 128 \
    AutoL \
    --template *cls**sent_0*_It_was*mask*.*sep+* \
    --mapping_path auto_label_mapping/CoLa/16-13.sort.txt
